# %% [markdown]
# # Section 6: Exploratory Data Analysis

# %% [markdown]
# ## 1. Filtering

# %%
import pandas as pd

groceries = pd.read_pickle('../Data/groceries_with_new_columns.pkl')
groceries.dtypes
# Out:
# Product_ID                         object
# Product_ID_Num                      int64
# Category                           object
# Subcategory                        object
# Item                               object
# Organic                              bool
# Price_Dollars                     float64
# Inventory                           int64
# Percent Inventory                 float64
# Low Inventory                      object
# Last_Updated               datetime64[ns]
# Last_Updated_Time                  object
# Next_Scheduled_Shipment    datetime64[ns]
# Shipment_Date_DOW                  object
# dtype: object

# %%
student_data
# Out:
#      Hours of Sleep  Hours Studied  Grade on Test  Grade in Class  \
# 0         10.602667       4.586892             99       99.187294
# 1          8.172997       4.405120             72       67.070903
# 2          6.430132       0.519630             52       39.644696
# 3          7.963793       5.004348             80       61.843705
# 4          8.279421       2.984489             87      103.495002
# ..              ...            ...            ...             ...
# 195        4.155300       3.173197             59       56.110076
# 196        4.306093       2.765300             58       64.740320
# 197        4.686733       2.422294             58       49.462645
# 198        9.407950       5.290924             98       83.790217
# 199        5.989777       1.127786             54       56.194381
#
#      Cups of Coffee
# 0                 5
# 1                 3
# 2                 4
# 3                 1
# 4                 0
# ..              ...
# 195               2
# ...

# %%
sns.scatterplot(x=student_data['Hours of Sleep'], y=student_data['Grade on Test']);

# %%
sns.scatterplot

# %%
sns.scatterplot(data=student_data, x='Hours of Sleep', y='Grade on Test')

# %%
#groceries.isnull.values.any()
groceries.isnull().any(axis=1)
groceries[groceries.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Product_ID, Product_ID_Num, Category, Subcategory, Item, Organic, Price_Dollars, Inventory, Percent Inventory, Low Inventory, Last_Updated, Last_Updated_Time, Next_Scheduled_Shipment, Shipment_Date_DOW]
# Index: []

# %%
groceries[groceries["Category"]!="Produce"]
# Out:
#    Product_ID  Product_ID_Num Category     Subcategory                   Item  \
# 17    P100027          100027   Pantry          Snacks  Apple Sauce - organic
# 18    P100028          100028   Pantry          Snacks                  Chips
# 19    P100029          100029   Pantry          Snacks      Cookies (Oatmeal)
# 20    P100030          100030   Pantry          Snacks                Raisins
# 21    P100031          100031   Frozen   Frozen Snacks        Chicken Nuggets
# 22    P100032          100032   Frozen   Frozen Snacks            Spinach Dip
# 23    P100033          100033   Frozen    Frozen Fruit     Frozen Blueberries
# 24    P100034          100034   Frozen    Frozen Fruit       Frozen Pineapple
#
#     Organic  Price_Dollars  Inventory  Percent Inventory  Low Inventory  \
# 17     True           1.50         27                0.6  Low Inventory
# 18    False           2.50        365                7.5
# 19    False           5.39        340                7.0
# ...

# %%
groceries[groceries["Price_Dollars"]<=5]
# Out:
#    Product_ID  Product_ID_Num Category     Subcategory                   Item  \
# 0     P100010          100010  Produce           Fruit                  Apple
# 1     P100011          100011  Produce           Fruit                 Banana
# 2     P100012          100012  Produce           Fruit                 Grapes
# 3     P100013          100013  Produce           Fruit             Grapefruit
# 4     P100014          100014  Produce           Fruit   Organic Strawberries
# 6     P100016          100016  Produce       Vegetable                Cabbage
# 7     P100017          100017  Produce       Vegetable                Carrots
# 8     P100018          100018  Produce       Vegetable                 Celery
# 9     P100019          100019  Produce       Vegetable               Cucumber
# 13    P100023          100023  Produce           Dairy                 Butter
# 14    P100024          100024  Produce           Dairy                   Eggs
# ...

# %%
# filter on low inventory
groceries[groceries['Low Inventory'] == 'Low Inventory']
# Out:
#    Product_ID  Product_ID_Num Category Subcategory                   Item  \
# 15    P100025          100025  Produce       Dairy             Milk (Soy)
# 17    P100027          100027   Pantry      Snacks  Apple Sauce - organic
# 20    P100030          100030   Pantry      Snacks                Raisins
#
#     Organic  Price_Dollars  Inventory  Percent Inventory  Low Inventory  \
# 15    False           4.49         32                0.7  Low Inventory
# 17     True           1.50         27                0.6  Low Inventory
# 20    False           2.99          5                0.1  Low Inventory
#
#           Last_Updated Last_Updated_Time Next_Scheduled_Shipment  \
# 15 2023-06-13 08:37:00          08:37:00              2023-06-17
# 17 2023-06-10 12:02:00          12:02:00              2023-06-24
# 20 2023-06-10 12:38:00          12:38:00              2023-06-24
#
#    Shipment_Date_DOW
# 15          Saturday
# 17          Saturday
# 20          Saturday

# %%
# compare with .loc
# groceries.loc[groceries['Low Inventory'] == 'Low Inventory', ['Price_Dollars', 'Inventory']]
# Out:
#     Price_Dollars  Inventory
# 15           4.49         32
# 17           1.50         27
# 20           2.99          5

# %%
# filter on the snacks subcategory
groceries[(groceries['Subcategory'] == ' Fruit') | (groceries['Subcategory'] == ' Snacks')] ### " | " or operation
groceries[(groceries['Subcategory'] == ' Fruit') | (groceries['Subcategory'] == ' Snacks')] ### " & " and operation for multiple condition
# Out:
#    Product_ID  Product_ID_Num Category Subcategory                   Item  \
# 0     P100010          100010  Produce       Fruit                  Apple
# 1     P100011          100011  Produce       Fruit                 Banana
# 2     P100012          100012  Produce       Fruit                 Grapes
# 3     P100013          100013  Produce       Fruit             Grapefruit
# 4     P100014          100014  Produce       Fruit   Organic Strawberries
# 5     P100015          100015  Produce       Fruit             Watermelon
# 17    P100027          100027   Pantry      Snacks  Apple Sauce - organic
# 18    P100028          100028   Pantry      Snacks                  Chips
# 19    P100029          100029   Pantry      Snacks      Cookies (Oatmeal)
# 20    P100030          100030   Pantry      Snacks                Raisins
#
#     Organic  Price_Dollars  Inventory  Percent Inventory  Low Inventory  \
# 0     False           1.50        349                7.2
# ...

# %%
#groceries[groceries["Subcategory"]=="Fruit"]
groceries["Subcategory"].value_counts()
# Out:
# Fruit            6
# Vegetable        4
# Dairy            4
# Snacks           4
# Meat             3
# Frozen Snacks    2
# Frozen Fruit     2
# Name: Subcategory, dtype: int64

# %%
# check one value
groceries['Subcategory'][1]
# Out:
# ' Fruit'

# %%
groceries[groceries['Category'].str.contains("PR")] ###sub string method
# Out:
# Empty DataFrame
# Columns: [Product_ID, Product_ID_Num, Category, Subcategory, Item, Organic, Price_Dollars, Inventory, Percent Inventory, Low Inventory, Last_Updated, Last_Updated_Time, Next_Scheduled_Shipment, Shipment_Date_DOW]
# Index: []

# %%
groceries
# Out:
#    Product_ID  Product_ID_Num Category     Subcategory                   Item  \
# 0     P100010          100010  Produce           Fruit                  Apple
# 1     P100011          100011  Produce           Fruit                 Banana
# 2     P100012          100012  Produce           Fruit                 Grapes
# 3     P100013          100013  Produce           Fruit             Grapefruit
# 4     P100014          100014  Produce           Fruit   Organic Strawberries
# 5     P100015          100015  Produce           Fruit             Watermelon
# 6     P100016          100016  Produce       Vegetable                Cabbage
# 7     P100017          100017  Produce       Vegetable                Carrots
# 8     P100018          100018  Produce       Vegetable                 Celery
# 9     P100019          100019  Produce       Vegetable               Cucumber
# 10    P100020          100020  Produce            Meat                   Beef
# ...

# %%
# strip then filter
groceries['Subcategory'] = groceries["Subcategory"].str.strip()

# %%
df2=["Dairy","Snacks","Meat"]
groceries[groceries["Subcategory"].isin(df2)] #$### isin a member ship test
# Out:
#    Product_ID  Product_ID_Num Category Subcategory                   Item  \
# 10    P100020          100020  Produce        Meat                   Beef
# 11    P100021          100021  Produce        Meat      Chicken (Organic)
# 12    P100022          100022  Produce        Meat                 Turkey
# 13    P100023          100023  Produce       Dairy                 Butter
# 14    P100024          100024  Produce       Dairy                   Eggs
# 15    P100025          100025  Produce       Dairy             Milk (Soy)
# 16    P100026          100026  Produce       Dairy                 Yogurt
# 17    P100027          100027   Pantry      Snacks  Apple Sauce - organic
# 18    P100028          100028   Pantry      Snacks                  Chips
# 19    P100029          100029   Pantry      Snacks      Cookies (Oatmeal)
# 20    P100030          100030   Pantry      Snacks                Raisins
#
#     Organic  Price_Dollars  Inventory  Percent Inventory  Low Inventory  \
# ...

# %%
groceries.sort_index(axis=1)
groceries.sort_index(ascending=False,axis=1)
groceries.sort_index(ascending=False)
groceries.sort_values("Price_Dollars",ascending=False)
# Out:
#    Product_ID  Product_ID_Num Category    Subcategory                   Item  \
# 23    P100033          100033   Frozen   Frozen Fruit     Frozen Blueberries
# 11    P100021          100021  Produce           Meat      Chicken (Organic)
# 10    P100020          100020  Produce           Meat                   Beef
# 12    P100022          100022  Produce           Meat                 Turkey
# 24    P100034          100034   Frozen   Frozen Fruit       Frozen Pineapple
# 21    P100031          100031   Frozen  Frozen Snacks        Chicken Nuggets
# 5     P100015          100015  Produce          Fruit             Watermelon
# 19    P100029          100029   Pantry         Snacks      Cookies (Oatmeal)
# 22    P100032          100032   Frozen  Frozen Snacks            Spinach Dip
# 15    P100025          100025  Produce          Dairy             Milk (Soy)
# 2     P100012          100012  Produce          Fruit                 Grapes
# ...

# %%
groceries[groceries["Subcategory"].str.contains("Sn")]
# Out:
#    Product_ID  Product_ID_Num Category    Subcategory                   Item  \
# 17    P100027          100027   Pantry         Snacks  Apple Sauce - organic
# 18    P100028          100028   Pantry         Snacks                  Chips
# 19    P100029          100029   Pantry         Snacks      Cookies (Oatmeal)
# 20    P100030          100030   Pantry         Snacks                Raisins
# 21    P100031          100031   Frozen  Frozen Snacks        Chicken Nuggets
# 22    P100032          100032   Frozen  Frozen Snacks            Spinach Dip
#
#     Organic  Price_Dollars  Inventory  Percent Inventory  Low Inventory  \
# 17     True           1.50         27                0.6  Low Inventory
# 18    False           2.50        365                7.5
# 19    False           5.39        340                7.0
# 20    False           2.99          5                0.1  Low Inventory
# 21    False           6.99         85                1.8
# ...

# %%
groceries[(groceries['Low Inventory'] == 'Low Inventory') & (groceries['Subcategory'] == 'Snacks')]
# Out:
#    Product_ID  Product_ID_Num Category Subcategory                   Item  \
# 17    P100027          100027   Pantry      Snacks  Apple Sauce - organic
# 20    P100030          100030   Pantry      Snacks                Raisins
#
#     Organic  Price_Dollars  Inventory  Percent Inventory  Low Inventory  \
# 17     True           1.50         27                0.6  Low Inventory
# 20    False           2.99          5                0.1  Low Inventory
#
#           Last_Updated Last_Updated_Time Next_Scheduled_Shipment  \
# 17 2023-06-10 12:02:00          12:02:00              2023-06-24
# 20 2023-06-10 12:38:00          12:38:00              2023-06-24
#
#    Shipment_Date_DOW
# 17          Saturday
# 20          Saturday

# %%
# filter on low inventory snacks
# mask = (groceries['Low Inventory'] == 'Low Inventory') & (groceries.Subcategory == 'Snacks')
# groceries[mask]

# %%
# filter rows and columns
#groceries.loc[mask, ['Subcategory', 'Item', 'Inventory']]

# %% [markdown]
# ## 2. Sorting

# %%
# filter on price
groceries.dtypes#.sort_values('Price_Dollars').head()
# Out:
# Product_ID                         object
# Product_ID_Num                      int64
# Category                           object
# Subcategory                        object
# Item                               object
# Organic                              bool
# Price_Dollars                     float64
# Inventory                           int64
# Percent Inventory                 float64
# Low Inventory                      object
# Last_Updated               datetime64[ns]
# Last_Updated_Time                  object
# Next_Scheduled_Shipment    datetime64[ns]
# Shipment_Date_DOW                  object
# dtype: object

# %%
# filter on price descending
groceries.sort_values('Price_Dollars', ascending=False).head()
# Out:
#    Product_ID  Product_ID_Num Category   Subcategory                Item  \
# 23    P100033          100033   Frozen  Frozen Fruit  Frozen Blueberries
# 11    P100021          100021  Produce          Meat   Chicken (Organic)
# 10    P100020          100020  Produce          Meat                Beef
# 12    P100022          100022  Produce          Meat              Turkey
# 24    P100034          100034   Frozen  Frozen Fruit    Frozen Pineapple
#
#     Organic  Price_Dollars  Inventory  Percent Inventory Low Inventory  \
# 23    False          10.99        162                3.3
# 11     True          10.49        284                5.8
# 10    False           8.99        145                3.0
# 12    False           7.99        188                3.9
# 24    False           7.96        178                3.7
#
#           Last_Updated Last_Updated_Time Next_Scheduled_Shipment  \
# 23 2023-05-28 22:14:00          22:14:00              2023-06-28
# ...

# %%
groceries["Item"].value_counts()
# Out:
# Apple                    1
# Butter                   1
# Frozen Blueberries       1
# Spinach Dip              1
# Chicken Nuggets          1
# Raisins                  1
# Cookies (Oatmeal)        1
# Chips                    1
# Apple Sauce - organic    1
# Yogurt                   1
# Milk (Soy)               1
# Eggs                     1
# Turkey                   1
# Banana                   1
# Chicken (Organic)        1
# Beef                     1
# Cucumber                 1
# Celery                   1
# Carrots                  1
# Cabbage                  1
# Watermelon               1
# Organic Strawberries     1
# Grapefruit               1
# Grapes                   1
# Frozen Pineapple         1
# Name: Item, dtype: int64

# %%
# chain on sort_values
groceries[groceries['Low Inventory'] == 'Low Inventory'].sort_values('Price_Dollars')
# Out:
#    Product_ID  Product_ID_Num Category Subcategory                   Item  \
# 17    P100027          100027   Pantry      Snacks  Apple Sauce - organic
# 20    P100030          100030   Pantry      Snacks                Raisins
# 15    P100025          100025  Produce       Dairy             Milk (Soy)
#
#     Organic  Price_Dollars  Inventory  Percent Inventory  Low Inventory  \
# 17     True           1.50         27                0.6  Low Inventory
# 20    False           2.99          5                0.1  Low Inventory
# 15    False           4.49         32                0.7  Low Inventory
#
#           Last_Updated Last_Updated_Time Next_Scheduled_Shipment  \
# 17 2023-06-10 12:02:00          12:02:00              2023-06-24
# 20 2023-06-10 12:38:00          12:38:00              2023-06-24
# 15 2023-06-13 08:37:00          08:37:00              2023-06-17
#
#    Shipment_Date_DOW
# 17          Saturday
# 20          Saturday
# 15          Saturday

# %%
groceries[groceries["Category"]=="Frozen"]["Subcategory"].value_counts()
# Out:
#  Frozen Snacks    2
#  Frozen Fruit     2
# Name: Subcategory, dtype: int64

# %%
groceries.groupby(["Category"])["Price_Dollars"].sum()
# Out:
# Category
# Frozen     30.90
# Pantry     12.38
# Produce    63.38
# Name: Price_Dollars, dtype: float64

# %%
groceries.groupby(["Category", "Subcategory"])["Price_Dollars"].sum()
# Out:
# Category  Subcategory
# Frozen     Frozen Fruit     18.95
#            Frozen Snacks    11.95
# Pantry     Snacks           12.38
# Produce    Dairy            12.28
#            Fruit            16.87
#            Meat             27.47
#            Vegetable         6.76
# Name: Price_Dollars, dtype: float64

# %%
groceries.groupby(["Category", "Subcategory"])["Price_Dollars"]
.agg(["mean", "max","min"])#.reset_index()
# Out:
#                              mean    max   min
# Category Subcategory
# Frozen    Frozen Fruit   9.475000  10.99  7.96
#           Frozen Snacks  5.975000   6.99  4.96
# Pantry    Snacks         3.095000   5.39  1.50
# Produce   Dairy          3.070000   4.49  1.00
#           Fruit          2.811667   5.99  0.40
#           Meat           9.156667  10.49  7.99
#           Vegetable      1.690000   2.00  0.99

# %%
groceries.groupby(["Category", "Subcategory"])["Price_Dollars"]
.agg(["mean", "max","min"]).reset_index()
# Out:
#   Category     Subcategory      mean    max   min
# 0   Frozen    Frozen Fruit  9.475000  10.99  7.96
# 1   Frozen   Frozen Snacks  5.975000   6.99  4.96
# 2   Pantry          Snacks  3.095000   5.39  1.50
# 3  Produce           Dairy  3.070000   4.49  1.00
# 4  Produce           Fruit  2.811667   5.99  0.40
# 5  Produce            Meat  9.156667  10.49  7.99
# 6  Produce       Vegetable  1.690000   2.00  0.99

# %%
groceries.groupby(["Category", "Subcategory"]).agg({"Price_Dollars":["mean","max"],
                                                   "Inventory":"min",
                                                   "Percent Inventory":"max"})
# Out:
#                         Price_Dollars        Inventory Percent Inventory
#                                  mean    max       min               max
# Category Subcategory
# Frozen    Frozen Fruit       9.475000  10.99       162               3.7
#           Frozen Snacks      5.975000   6.99        76               1.8
# Pantry    Snacks             3.095000   5.39         5               7.5
# Produce   Dairy              3.070000   4.49        32               8.9
#           Fruit              2.811667   5.99        50              10.3
#           Meat               9.156667  10.49       145               5.8
#           Vegetable          1.690000   2.00        50               4.7

# %%
groceries["Price_Dollars"].mode()
# Out:
# 0    0.99
# 1    1.50
# Name: Price_Dollars, dtype: float64

# %% [markdown]
# ## 3. Group By

# %%
# group by category
groceries.groupby('Category')

# %%
# group by category and show total inventory
groceries.groupby('Category')['Inventory'].sum()
# Out:
# Category
# Frozen      501
# Pantry      737
# Produce    3619
# Name: Inventory, dtype: int64

# %%
# group by category and unique items
groceries.groupby('Category')['Inventory'].count()
# Out:
# Category
# Frozen      4
# Pantry      4
# Produce    17
# Name: Inventory, dtype: int64

# %%
# group by category and subcategory and unique items
groceries.groupby(['Category', 'Subcategory'])['Inventory'].count().reset_index()
# Out:
#   Category    Subcategory  Inventory
# 0   Frozen   Frozen Fruit          2
# 1   Frozen  Frozen Snacks          2
# 2   Pantry         Snacks          4
# 3  Produce          Dairy          4
# 4  Produce          Fruit          6
# 5  Produce           Meat          3
# 6  Produce      Vegetable          4

# %%
# group by category and subcategory and unique items
groceries.groupby(['Category', 'Subcategory'])['Inventory'].agg(['sum', 'count']).reset_index()
# Out:
#   Category    Subcategory   sum  count
# 0   Frozen   Frozen Fruit   340      2
# 1   Frozen  Frozen Snacks   161      2
# 2   Pantry         Snacks   737      4
# 3  Produce          Dairy  1098      4
# 4  Produce          Fruit  1346      6
# 5  Produce           Meat   617      3
# 6  Produce      Vegetable   558      4

# %%
# group by category and show max priced item
groceries.groupby('Category')['Price_Dollars'].max().reset_index()
# Out:
#   Category  Price_Dollars
# 0   Frozen          10.99
# 1   Pantry           5.39
# 2  Produce          10.49

# %%
# group by category and show the item -- THIS IS INCORRECT!
groceries.groupby('Category')[['Item','Price_Dollars']].max()
# Out:
#                  Item  Price_Dollars
# Category
# Frozen    Spinach Dip          10.99
# Pantry        Raisins           5.39
# Produce        Yogurt          10.49

# %%
# this is correct
(groceries[['Category', 'Item', 'Price_Dollars']]
 .sort_values('Price_Dollars', ascending=False)
 .groupby('Category').head(1))
# Out:
#    Category                Item  Price_Dollars
# 23   Frozen  Frozen Blueberries          10.99
# 11  Produce   Chicken (Organic)          10.49
# 19   Pantry   Cookies (Oatmeal)           5.39

# %% [markdown]
# ## 4. Pandas Plots

# %%
groceries.head()
# Out:
#   Product_ID  Product_ID_Num Category Subcategory                  Item  \
# 0    P100010          100010  Produce       Fruit                 Apple
# 1    P100011          100011  Produce       Fruit                Banana
# 2    P100012          100012  Produce       Fruit                Grapes
# 3    P100013          100013  Produce       Fruit            Grapefruit
# 4    P100014          100014  Produce       Fruit  Organic Strawberries
#
#    Organic  Price_Dollars  Inventory  Percent Inventory Low Inventory  \
# 0    False           1.50        349                7.2
# 1    False           0.40        500               10.3
# 2    False           4.00        200                4.1
# 3    False           0.99         50                1.0
# 4     True           3.99        148                3.0
#
#          Last_Updated Last_Updated_Time Next_Scheduled_Shipment  \
# 0 2023-06-12 15:35:00          15:35:00              2023-06-15
# ...

# %%
groceries.groupby('Subcategory')['Price_Dollars'].sum().sort_values().plot.bar();

# %%
# create a bar chart
groceries.groupby('Subcategory')['Price_Dollars'].mean().sort_values().plot.barh();

# %%
# create a horizontal bar chart
groceries.groupby('Subcategory')['Price_Dollars'].mean().sort_values().plot.bar();

# %%
# create a horizontal bar chart with sorted values
groceries.groupby('Subcategory')['Price_Dollars'].mean().sort_values().plot.barh();

# %%
import pandas as pd

happiness = pd.read_csv('../Data/happiness_survey_data.csv')
happiness.head()
# Out:
#   country_name  year  happiness_score  social_support  \
# 0  Afghanistan  2008         3.723590        0.450662
# 1  Afghanistan  2009         4.401778        0.552308
# 2  Afghanistan  2010         4.758381        0.539075
# 3  Afghanistan  2011         3.831719        0.521104
# 4  Afghanistan  2012         3.782938        0.520637
#
#    freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 0                      0.718114                         50.500000
# 1                      0.678896                         50.799999
# 2                      0.600127                         51.099998
# 3                      0.495901                         51.400002
# 4                      0.530935                         51.700001

# %%
happiness[happiness["country_name"]=="India"][["year","happiness_score"]].plot.line(x="year",y="happiness_score");

# %%
# create a line chart for Mexico's happiness scores
happiness[happiness.country_name == 'Mexico'].iloc[:, 1:3].plot.line(x='year', y='happiness_score');

# %%
# create a line chart for Mexico's happiness scores
happiness[happiness.country_name == 'India'][["year","happiness_score"]].plot.line(x='year', y='happiness_score');

# %%
# subset and pivot data to create multiple plots
(happiness[happiness.country_name.isin(['Canada', 'Mexico','United States'])]
                                 .iloc[:, :3]
                                 .pivot(index='year', columns='country_name', values='happiness_score'))
# Out:
# country_name    Canada    Mexico  United States
# year
# 2005          7.418048  6.580658            NaN
# 2006               NaN       NaN       7.181794
# 2007          7.481753  6.525378       7.512688
# 2008          7.485604  6.829036       7.280386
# 2009          7.487824  6.962819       7.158032
# 2010          7.650346  6.802389       7.163616
# 2011          7.426054  6.909515       7.115139
# 2012          7.415144  7.320185       7.026227
# 2013          7.593794  7.442546       7.249285
# 2014          7.304258  6.679831       7.151114
# 2015          7.412773  6.236287       6.863947
# 2016          7.244846  6.824173       6.803600
# 2017          7.414868  6.410299       6.991759
# 2018          7.175497  6.549579       6.882685
# 2019          7.109076  6.431945       6.943701
# 2020          7.024905  5.964221       7.028088
# 2021          6.939435  5.990751       6.959088

# %%
# create a line chart with multiple lines
(happiness[happiness.country_name.isin(['Canada', 'Mexico','United States'])]
                                 .iloc[:, :3]
                                 .pivot(index='year', columns='country_name', values='happiness_score')
                                 .plot());

# %% [markdown]
# ## 5. Pair Plot

# %%
import seaborn as sns

student_data = pd.read_csv('../Data/student_data.csv')
student_data.dtypes
# Out:
# Hours of Sleep    float64
# Hours Studied     float64
# Grade on Test       int64
# Grade in Class    float64
# Cups of Coffee      int64
# dtype: object

# %%
sns.pairplot(student_data);

# %% [markdown]
# ## 6. More Plots

# %%
student_data['Cups of Coffee']
# Out:
# 0       5
# 1       3
# 2       4
# 3       1
# 4       0
#        ..
# 195     2
# 196     1
# 197     1
# 198    10
# 199     2
# Name: Cups of Coffee, Length: 200, dtype: int64

# %%
# frequency table of discrete data
(student_data['Cups of Coffee'].value_counts()
                               .sort_index())
# Out:
# 0     35
# 1     67
# 2     44
# 3     38
# 4      6
# 5      5
# 6      3
# 8      1
# 10     1
# Name: Cups of Coffee, dtype: int64

# %%
# histogram
sns.histplot(student_data['Cups of Coffee'])
# Out:
# <AxesSubplot:xlabel='Cups of Coffee', ylabel='Count'>

# %%
# another histogram
sns.histplot(student_data['Cups of Coffee'],
             bins=10, color='purple');

# %%
# frequency table of continuous data
student_data['Hours Studied'].round().value_counts().sort_index()
# Out:
# 0.0     4
# 1.0    18
# 2.0    23
# 3.0    53
# 4.0    38
# 5.0    37
# 6.0    19
# 7.0     7
# 8.0     1
# Name: Hours Studied, dtype: int64

# %%
# histogram of continuous data
sns.histplot(student_data['Hours Studied'])
# Out:
# <AxesSubplot:xlabel='Hours Studied', ylabel='Count'>

# %%
# scatter plot of data
sns.scatterplot(data=student_data, x='Hours of Sleep', y='Grade on Test')
# Out:
# <AxesSubplot:xlabel='Hours of Sleep', ylabel='Grade on Test'>

# %%
# digging into an outlier
student_data[student_data['Hours of Sleep'] < 3]
# Out:
#      Hours of Sleep  Hours Studied  Grade on Test  Grade in Class  \
# 12         2.000000       4.743829             98      102.670751
# 67         2.741172       3.498785             51       56.135378
# 97         2.130628       4.951326             55       48.417485
# 148        1.899843       1.584035             59       50.616890
#
#      Cups of Coffee
# 12                1
# 67                3
# 97                1
# 148               5

# %%
# correlation table
corr=student_data.corr()
corr
# Out:
#                 Hours of Sleep  Hours Studied  Grade on Test  Grade in Class  \
# Hours of Sleep        1.000000       0.265404       0.637864        0.502397
# Hours Studied         0.265404       1.000000       0.479153        0.374456
# Grade on Test         0.637864       0.479153       1.000000        0.815721
# Grade in Class        0.502397       0.374456       0.815721        1.000000
# Cups of Coffee       -0.079643      -0.020209      -0.038804       -0.035288
#
#                 Cups of Coffee
# Hours of Sleep       -0.079643
# Hours Studied        -0.020209
# Grade on Test        -0.038804
# Grade in Class       -0.035288
# Cups of Coffee        1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >
